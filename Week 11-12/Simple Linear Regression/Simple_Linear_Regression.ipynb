# %% [markdown]
# <a href="https://colab.research.google.com/github/sabrinaangel/ml-dataset-preprocessing/blob/main/Week%2011-12/Simple%20Linear%20Regression/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Linear Regression
# - Pada tutorial kali ini, kita akan menggunakan sebuah dataset yang memiliki 2 features, yaitu horsepower dan price dari sebuah mobil
# - Tujuan dari tutorial ini adalah memprediksi harga mobil jika mobil tersebut mempunyai horsepower sebesar 100, 150, dan 200
# - Hipotesis awal : mobil dengan horsepower lebih tinggi harganya lebih mahal jika dibandingkan dengan yang horsepowernya lebih rendah.

# %% [markdown]
# ### Load library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load datasets

# %%
#Nama dataframe kita adalah df yang berisi data dari data.csv
#Hanya menggunakan kolom horsepower dan price
df = pd.read_csv('data.csv', usecols=['horsepower', 'price'])

# %% [markdown]
# ### Sneak peak data

# %%
#Melihat 5 baris teratas dari data
#Independent variabel(x) adalah horsepower
#Dependent variabel(y) adalah price
df.head()
# Out:
#    horsepower    price
# 0       111.0  13495.0
# 1       111.0  16500.0
# 2       154.0  16500.0
# 3       102.0  13950.0
# 4       115.0  17450.0

# %%
#Mengetahui jumlah kolom dan baris dari data
#Data kita mempunya 2 kolom dengan 200 baris
df.shape
# Out:
# (200, 2)

# %%
#Melihat informasi data kita mulai dari jumlah data, tipe data, memory yang digunakan dll.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   horsepower  200 non-null    float64
#  1   price       200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
#Melihat statistical description dari data mulai dari mean, kuartil, standard deviation dll
df.describe()
# Out:
#        horsepower         price
# count  200.000000    200.000000
# mean   103.320000  13230.375000
# std     37.468615   7960.155239
# min     48.000000   5118.000000
# 25%     70.000000   7775.000000
# 50%     95.000000  10320.000000
# 75%    116.000000  16500.750000
# max    262.000000  45400.000000

# %% [markdown]
# ### Handling Missing Values

# %%
#Mencari dan menangani missing values
#Ternyata data kita tidak ada missing values
df.isnull().sum()
# Out:
# horsepower    0
# price         0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
#Univariate analysis horsepower
#Melihat distribusi dari horsepower
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['horsepower'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['horsepower'])
plt.show()

# %% [markdown]
# - Dapat dilihat bahwa density dari horsepower paling tinggi di nilai 100.
# - Distribusinya hampir mirip dengan distribusi normal namun persebaran data kurang merata (memiliki standard deviasi yang tinggi).

# %%
#Univariate analysis price
#Melihat distribusi dari price
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['price'].plot(kind='kde', c='g')

f.add_subplot(1,2,2)
plt.boxplot(df['price'])
plt.show()

# %% [markdown]
# - Density dari price paling tinggi di nilai 10000.
# - Distribusinya hampir mirip dengan distribusi normal namun persebaran data kurang merata (memiliki standard deviasi yang tinggi).

# %%
#Bivariate analysis horsepower dan price
#Menggunakan scatter plot
plt.scatter(df['horsepower'], df['price'])
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Scatter Plot Horsepower vs Price')
plt.show()

# %% [markdown]
# - Dari scatter plot dapat dilihat bahwa data memiliki korelasi positif yang cukup signifikan.
# - Hal ini berarti dengan bertambahnya nilai dari horsepower maka nilai price pun akan bertambah

# %%
#Mengetahui nilai korelasi dari horsepower dan price
#Nilai korelasinya adalah 0.81 termasuk kategori sangat tinggi
df.corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.811097
# price         0.811097  1.000000

# %% [markdown]
# - Setelah kita tahu tentang karakteristik data kita, bisa dilanjutkan ke tahap modelling

# %% [markdown]
# ### Modelling

# %%
#Recall data kita
df.head()
# Out:
#    horsepower    price
# 0       111.0  13495.0
# 1       111.0  16500.0
# 2       154.0  16500.0
# 3       102.0  13950.0
# 4       115.0  17450.0

# %%
#Pertama, buat variabel x dan y
x = df['horsepower'].values.reshape(-1,1)
y = df['price'].values.reshape(-1,1)

# %%
#Kedua, kita split data kita menjadi training and testing dengan porsi 80:20
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#Ketiga, kita bikin object linear regresi
lin_reg = LinearRegression()

# %%
#Keempat, train the model menggunakan training data yang sudah displit
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Kelima, cari tau nilai slope/koefisien (m) dan intercept (b)
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [[181.60241619]]
# [-5203.49938922]

# %% [markdown]
# - dari nilai m dan b diatas, kalau dimasukan ke dalam rumus menjadi:
# Y = 164.73x - 3903.39

# %%
#Keenam, kita cari tahu accuracy score dari model kita menggunakan testing data yang sudah displit
lin_reg.score(x_test, y_test)
# Out:
# 0.5534644641248996

# %% [markdown]
# - Model kita mendapatkan accuracy score sebesar 78.68%

# %%
#Ketujuh, visualisasi aktual vs prediksi menggunakan data testing
#Garis merah merupakan garis regresi dari persamaan yang kita dapat tadi
y_prediksi = lin_reg.predict(x_test)
plt.scatter(x_test, y_test)
plt.plot(x_test, y_prediksi, c='r')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Plot Horsepower vs Price')
# Out:
# Text(0.5, 1.0, 'Plot Horsepower vs Price')

# %% [markdown]
# ### Prediction
# - Yuk kita prediksi harga mobil ketika memiliki horsepower 100, 150, dan 200

# %%
#Prediksi harga mobil dengan horsepower 100
lin_reg.predict([[100]])
# Out:
# array([[12956.74222969]])

# %%
#Prediksi harga mobil dengan horsepower 150
lin_reg.predict([[150]])
# Out:
# array([[22036.86303914]])

# %%
#Prediksi harga mobil dengan horsepower 200
lin_reg.predict([[200]])
# Out:
# array([[31116.9838486]])

# %% [markdown]
# ### Test Your Own Prediction
# Let's try to predict the price for a horsepower value you provide.

# %%
def predict_price_for_horsepower(hp_value):
    """
    Predicts the price of a car given its horsepower using the trained linear regression model.
    """
    # The model expects a 2D array, so reshape the input.
    predicted_price = lin_reg.predict([[hp_value]])
    return predicted_price[0][0]

# Get user input for horsepower
# Make sure to handle potential errors if the input is not a number
try:
    user_horsepower = float(input("Enter a horsepower value to predict the price: "))
    predicted_val = predict_price_for_horsepower(user_horsepower)
    print(f"The predicted price for a car with {user_horsepower} horsepower is: ${predicted_val:.2f}")
except ValueError:
    print("Invalid input. Please enter a numerical value for horsepower.")
# Out:
# Enter a horsepower value to predict the price: 1000
# The predicted price for a car with 1000.0 horsepower is: $176398.92

# %% [markdown]
# - dengan melihat prediksi harga diatas, didapatkan bahwa hipotesis awal kita memang benar yaitu mobil dengan Horsepower 200 memiliki harga yang lebih mahal daripada yang lain!

# %% [markdown]
# ## Resources
# - **Scikit-learn (Linear Regression Documentation)**: [https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
# - **Pandas Documentation**: [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)
# - **Matplotlib Documentation**: [https://matplotlib.org/stable/contents/index.html](https://matplotlib.org/stable/contents/index.html)
# - **Simple Linear Regression Explained (Article/Tutorial)**: (You can replace this with a specific tutorial link, e.g., from Towards Data Science, Kaggle, etc.)
