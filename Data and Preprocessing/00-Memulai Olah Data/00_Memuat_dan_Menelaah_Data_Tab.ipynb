# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/ML_Praktikum/Minggu-2/python/Data dan Preprocessing/00-Memulai Olah Data')

# %%
# Cek apakah kita sudah di folder yang bener
print("Sekarang di folder:", os.getcwd())

# Lihat isi folder (Menampilkan semua file dan folder yang ada di folder aktif. Buat mastiin file Tab.csv beneran ada di folder ini.)
print("Isi folder:", os.listdir())

# Baca file CSV (memuat dataset ke Python.)
import pandas as pd #manggil library pandas (buat olah data)
df = pd.read_csv('Tab.csv') #baca file CSV dan masukin ke variabel df

# Lihat isinya (Nampilin 5 baris pertama dari dataset.)
df.head()
# Out:
# Sekarang di folder: /content/drive/MyDrive/ML_Praktikum/Minggu-2/python/Data dan Preprocessing/00-Memulai Olah Data
# Isi folder: ['Tab.csv', 'startPython.ipynb', '.ipynb_checkpoints']
#   Unnamed: 0     Negara  Populasi    Area    Ibukota
# 0         IN  Indonesia       250  123456    Jakarta
# 1         MA   Malaysia        25    3456         KL
# 2         SI  Singapura        15     456  Singapura
# 3         JP     Jepang        60    5678      Tokyo
# 4         TH   Thailand        45     678    Bangkok

# %%
df.info()        # lihat tipe data dan missing values
df.describe()    # statistik dasar (mean, min, max, dll)
df.shape         # jumlah baris dan kolom
df.columns       # nama-nama kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
#  1   Negara      5 non-null      object
#  2   Populasi    5 non-null      int64
#  3   Area        5 non-null      int64
#  4   Ibukota     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes
# Index(['Unnamed: 0', 'Negara', 'Populasi', 'Area', 'Ibukota'], dtype='object')

# %%
# 1. Lihat 10 baris pertama
df.head(10)

# 2. Lihat 5 baris terakhir
df.tail()

# 3. Lihat informasi lengkap dataset
df.info()

# 4. Lihat statistik dasar (kalo kolomnya angka)
df.describe()

# 5. Lihat jumlah baris & kolom
print("Jumlah baris:", df.shape[0])
print("Jumlah kolom:", df.shape[1])

# 6. Lihat nama-nama kolom
print("Kolom:", df.columns.tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
#  1   Negara      5 non-null      object
#  2   Populasi    5 non-null      int64
#  3   Area        5 non-null      int64
#  4   Ibukota     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes
# Jumlah baris: 5
# Jumlah kolom: 5
# Kolom: ['Unnamed: 0', 'Negara', 'Populasi', 'Area', 'Ibukota']
